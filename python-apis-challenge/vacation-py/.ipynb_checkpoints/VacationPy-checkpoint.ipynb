# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather = pd.read_csv('../weatherPy/weather_data.csv')
weather = weather.drop('Unnamed: 0', axis = 1)

# %%
weather.head()
# Out:
#         City    Lat    Long  Max Temp  Humidity  Cloudiness (%)  \
# 0    Rikitea -23.12 -134.97    293.95        80              12
# 1    Ushuaia -54.80  -68.30    272.15        92              40
# 2   Saldanha -33.01   17.94    288.15        77               0
# 3  Bariloche -41.15  -71.31    274.15       100              75
# 4       Hilo  19.73 -155.09    301.15        65              90
#
#    Wind Speed (m/s) Country        Date  Max Temp Fahrenheit
# 0              9.84      PF  1595705224                69.71
# 1              9.30      AR  1595705226                30.47
# 2              0.50      ZA  1595705229                59.27
# 3              4.60      AR  1595705231                34.07
# 4              3.10      US  1595705233                82.67

# %%
#Lat/long list
lat = weather['Lat'].tolist()
long = weather['Long'].tolist()
coordinates = list(zip(lat, long))
coordinates
# Out:
# [(-23.12, -134.97),
#  (-54.8, -68.3),
#  (-33.01, 17.94),
#  (-41.15, -71.31),
#  (19.73, -155.09),
#  (62.46, -114.35),
#  (62.27, 24.7),
#  (-13.88, 167.55),
#  (-24.79, -50.01),
#  (-0.48, 15.9),
#  (35.13, 140.3),
#  (-33.93, 18.42),
#  (14.4, 46.47),
#  (77.48, -69.36),
#  (-34.42, 19.23),
#  (-21.36, 55.77),
#  (-20.52, 57.52),
#  (22.08, -159.32),
#  (71.29, -156.79),
#  (59.7, 30.79),
#  (42.1, -79.24),
#  (-46.6, 168.33),
#  (32.69, 128.84),
#  (-46.28, 169.85),
#  (34.64, -120.46),
#  (-53.15, -70.92),
#  (-46.19, 168.86),
#  (31.61, 34.76),
#  (-21.2, -175.2),
#  (-0.13, -67.09),
#  (46.43, 26.4),
#  (70.63, 147.92),
#  (68.75, 161.3),
#  (43.52, -8.15),
#  (-3.14, -58.44),
#  (47.62, -57.62),
#  (-6.88, 112.21),
#  (-34.53, 20.04),
#  (57.05, -135.33),
#  (19.73, 96.22),
#  (78.22, 15.64),
#  (40.83, -6.0),
#  (-15.86, -38.88),
#  (68.05, 39.51),
#  (28.46, 119.91),
#  (43.88, -91.24),
#  (28.82, 115.43),
#  (-8.47, 140.33),
#  (-33.92, 25.57),
#  (71.92, 114.08),
#  (61.67, 96.37),
#  (12.52, -70.03),
#  (39.18, -84.53),
#  (-0.81, 12.73),
#  (42.6, -73.97),
#  (65.7, 82.47),
#  (52.37, 9.73),
#  (45.02, -93.22),
#  (4.14, 96.13),
#  (-3.8, 102.27),
#  (64.5, -165.41),
#  (26.12, 127.67),
#  (8.0, 124.29),
#  (69.45, -133.04),
#  (71.97, 102.5),
#  (-31.95, 141.43),
#  (4.41, 114.01),
#  (-20.73, 139.5),
#  (-20.74, 116.85),
#  (41.14, -73.36),
#  (-34.65, 148.03),
#  (-33.65, 115.33),
#  (-16.43, -51.82),
#  (41.65, 26.47),
#  (57.79, -152.41),
#  (42.25, -75.83),
#  (-0.74, -90.35),
#  (-38.0, -57.56),
#  (29.57, -104.42),
#  (60.14, -45.24),
#  (-28.78, 32.04),
#  (7.53, -12.51),
#  (64.38, -173.3),
#  (-35.72, 150.18),
#  (20.45, 121.97),
#  (4.88, -1.76),
#  (-35.35, 150.47),
#  (51.38, -2.36),
#  (-19.12, 33.48),
#  (30.65, -91.16),
#  (-9.29, -76.01),
#  (66.08, 76.63),
#  (-38.65, 178.0),
#  (16.98, 73.3),
#  (69.3, 139.9),
#  (11.0, 122.67),
#  (-20.57, 164.28),
#  (6.5, 2.6),
#  (-6.34, 106.1),
#  (66.56, 67.8),
#  (-14.66, 17.69),
#  (19.87, 72.7),
#  (39.89, 4.27),
#  (44.26, 38.86),
#  (51.38, 1.39),
#  (-25.3, 152.85),
#  (-10.75, -77.77),
#  (37.08, 57.51),
#  (47.45, -79.64),
#  (50.7, -127.42),
#  (68.71, -52.87),
#  (10.92, -7.0),
#  (34.98, 139.87),
#  (-20.32, 118.57),
#  (47.8, 67.71),
#  (-13.7, -76.22),
#  (59.64, 17.08),
#  (10.93, 108.1),
#  (-10.88, 26.6),
#  (41.82, 140.65)]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#Configure gmaps
gmaps.configure(api_key=g_key)

# %%
#Configure the map layout
figure_layout = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %%
#Add markers corresponding to coordinates of each city
markers = gmaps.marker_layer(coordinates)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %%
weather.head()
humidity = weather.Humidity
type(humidity)
# Out:
# pandas.core.series.Series

# %%
#Add heatmap layer
heat_layer = gmaps.heatmap_layer(coordinates, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#Ideal weather conditions for me: max temp 77 deg fahrenheit or below, windspeed below 5 m/s, humidity 60% or below
weather_ideal = weather[weather['Wind Speed (m/s)']<5]
weather_ideal = weather_ideal[weather_ideal['Max Temp Fahrenheit']<77]
weather_ideal = weather_ideal[weather_ideal['Humidity']<60]
weather_ideal = weather_ideal.reset_index()
weather_ideal.head()
# Out:
#    index          City    Lat    Long  Max Temp  Humidity  Cloudiness (%)  \
# 0      8        Castro -24.79  -50.01    293.58        59             100
# 1     13       Qaanaaq  77.48  -69.36    280.66        56               0
# 2     25  Punta Arenas -53.15  -70.92    274.15        59              74
# 3     31    Chokurdakh  70.63  147.92    295.81        44             100
# 4     32      Cherskiy  68.75  161.30    295.91        50               0
#
#    Wind Speed (m/s) Country        Date  Max Temp Fahrenheit
# 0              2.84      BR  1595705242                69.04
# 1              1.01      GL  1595705254                45.79
# 2              4.60      CL  1595705222                34.07
# 3              2.71      RU  1595705301                73.06
# 4              1.55      RU  1595705303                73.24

# %%
#Drop nulls
weather_ideal_no_null = weather_ideal.dropna()
weather_ideal_no_null.head()
# Out:
#    index          City    Lat    Long  Max Temp  Humidity  Cloudiness (%)  \
# 0      8        Castro -24.79  -50.01    293.58        59             100
# 1     13       Qaanaaq  77.48  -69.36    280.66        56               0
# 2     25  Punta Arenas -53.15  -70.92    274.15        59              74
# 3     31    Chokurdakh  70.63  147.92    295.81        44             100
# 4     32      Cherskiy  68.75  161.30    295.91        50               0
#
#    Wind Speed (m/s) Country        Date  Max Temp Fahrenheit
# 0              2.84      BR  1595705242                69.04
# 1              1.01      GL  1595705254                45.79
# 2              4.60      CL  1595705222                34.07
# 3              2.71      RU  1595705301                73.06
# 4              1.55      RU  1595705303                73.24

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#Store ideal cities/weather into a variable called hotel_df
hotel_df = weather_ideal_no_null
hotel_df.head()
# Out:
#    index          City    Lat    Long  Max Temp  Humidity  Cloudiness (%)  \
# 0      8        Castro -24.79  -50.01    293.58        59             100
# 1     13       Qaanaaq  77.48  -69.36    280.66        56               0
# 2     25  Punta Arenas -53.15  -70.92    274.15        59              74
# 3     31    Chokurdakh  70.63  147.92    295.81        44             100
# 4     32      Cherskiy  68.75  161.30    295.91        50               0
#
#    Wind Speed (m/s) Country        Date  Max Temp Fahrenheit
# 0              2.84      BR  1595705242                69.04
# 1              1.01      GL  1595705254                45.79
# 2              4.60      CL  1595705222                34.07
# 3              2.71      RU  1595705301                73.06
# 4              1.55      RU  1595705303                73.24

# %%
#Ideal locations coordinates
ideal_lat = hotel_df['Lat'].tolist()
ideal_long = hotel_df['Long'].tolist()
ideal_coord = list(zip(ideal_lat, ideal_long))
ideal_coord
# Out:
# [(-24.79, -50.01),
#  (77.48, -69.36),
#  (-53.15, -70.92),
#  (70.63, 147.92),
#  (68.75, 161.3),
#  (-33.92, 25.57),
#  (45.52, -122.68),
#  (-33.02, 27.91),
#  (50.15, 48.57),
#  (-45.87, 170.5),
#  (38.5, 102.17),
#  (51.5, -107.05),
#  (48.01, 91.64),
#  (-26.18, -58.18),
#  (64.57, 143.2),
#  (-11.95, -75.28),
#  (31.76, 13.99),
#  (65.28, -126.83),
#  (-8.42, 20.74),
#  (45.75, 1.33),
#  (36.4, 47.11),
#  (-1.9, 34.02),
#  (-13.2, 49.05),
#  (-28.94, -51.55),
#  (-40.81, -63.0),
#  (48.57, 83.65),
#  (-29.95, -71.34),
#  (-34.0, 24.73),
#  (48.59, 57.19),
#  (58.81, -122.7),
#  (48.2, -114.31),
#  (-2.52, 32.9),
#  (62.67, 135.6),
#  (37.52, 42.46),
#  (-38.37, -60.28),
#  (-19.98, 57.61),
#  (-14.78, 24.8),
#  (34.17, 77.58),
#  (46.48, 30.73),
#  (-20.01, 57.66),
#  (50.06, 43.24),
#  (54.72, -113.29),
#  (62.88, 152.43),
#  (-9.54, 16.34),
#  (-33.89, -60.57),
#  (69.3, 139.9),
#  (-14.66, 17.69),
#  (47.8, 67.71),
#  (59.64, 17.08),
#  (-10.88, 26.6)]

# %%
#Add 'hotel name' column to the df
hotel_df['Hotel Name'] = ''
hotel_df.head()
# Out:
# C:\Users\flier\.conda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Params for google API search for hotels within 5000 m
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": "-24.79, -50.01",  #testing out ideal coordinate list,
    "radius": 5000,
    "types": "hotel",
    "key": g_key,
    "keyword": "hotel"
}

# %%
#Practice API call for first place on list
testresponse = requests.get(base_url, params=params)

# %%
testdata = testresponse.json()
testdata
#Test data is showing me I have to put the coordinates in manually as a string, so how can I loop thru them? 
#Also, how can i search thru the 'types' as 'hotel?'
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -24.7913347, 'lng': -50.0077557},
#     'viewport': {'northeast': {'lat': -24.78999402010727,
#       'lng': -50.00636957010728},
#      'southwest': {'lat': -24.79269367989271, 'lng': -50.00906922989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '79afacf023eb1ee928df545fff1fd5a767c37b04',
#    'name': 'Central Palace Hotel - Castro (PR)',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113611644224940597398">Hotel Central Palace</a>'],
#      'photo_reference': 'CmRaAAAAtwFAjc7NwRZM9MPaX_ta37lUEJZmTGlBB8UPGFocQpYjJJo0UyKV_bY40kjPHMfvfyetIJ4Uu36F60mZk6SNB48I-v59SVho3jTgkFBrDQDnC2w2_HVHhnIw_axA372EEhB6Yv9h2rtNTlkhKh6mJ6d1GhSba9g59qSV9V2DzLiuWPfyj-V9BQ',
#      'width': 1280}],
#    'place_id': 'ChIJP4uJvU2dwpQRi-9oeVlg6ng',
#    'plus_code': {'compound_code': '6X5R+FV Centro, Castro - State of Paraná, Brazil',
#     'global_code': '587F6X5R+FV'},
#    'rating': 4.1,
#    'reference': 'ChIJP4uJvU2dwpQRi-9oeVlg6ng',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 398,
#    'vicinity': 'R. Cipriano Marquês de Souza, 18 - Centro, Castro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -24.7840264, 'lng': -50.00596909999999},
#     'viewport': {'northeast': {'lat': -24.78269817010728,
#       'lng': -50.00457972010727},
#      'southwest': {'lat': -24.78539782989272, 'lng': -50.00727937989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '9d16836b32c856a7e04ddc533451306e4b921321',
#    'name': 'Pousada Rota Dos Tropeiros',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2096,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114760157127803595599">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAZ8-L9bRt5H_H9-BZyqEU_nHsKJhFN_uedqDlHVBgOfTY6haFEWGd9WLoWcxkNyghKl6L9aBjytvER3jStz38OkFPNGTpLohef5ZhVDHsJNbI3Xlgm0IX54PdTx-pskO6EhA3z2lf4rRz4YQFvMgvE6nMGhS2HkEZHWE9Eo21P9pKkLgzCUTTJw',
#      'width': 3724}],
#    'place_id': 'ChIJv36osoaDwpQR2LmnKEDX72g',
#    'plus_code': {'compound_code': '6X8V+9J Centro, Castro - State of Paraná, Brazil',
#     'global_code': '587F6X8V+9J'},
#    'rating': 4.5,
#    'reference': 'ChIJv36osoaDwpQR2LmnKEDX72g',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 159,
#    'vicinity': 'R. Pedro Kaled, 82 - Centro, Castro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -24.7914731, 'lng': -50.0080458},
#     'viewport': {'northeast': {'lat': -24.79016142010728,
#       'lng': -50.00654467010727},
#      'southwest': {'lat': -24.79286107989272, 'lng': -50.00924432989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'b870274ffd06421e6b64af45dc1660dee636e6ee',
#    'name': 'OYO Grande Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102769961985143012423">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAy06a8i3MJsLFVE0LB1a66Apcr4KX4BayZd0mqsiTWgjfYBwFf9nvPikZNT-XyIAXgprgmJMB7KHIxzp-lPn0LPUNI303WQHtG9FMvwYNtzjOP0Yko2BCvQb96gyBrLvgEhBmgX3s1euQ-jAU1aVWwEtFGhQcTtrDl_mUYmAo0LOwqNN1irgbSA',
#      'width': 2880}],
#    'place_id': 'ChIJsxDClU2dwpQRChZOS33Zup0',
#    'plus_code': {'compound_code': '6X5R+CQ Centro, Castro - State of Paraná, Brazil',
#     'global_code': '587F6X5R+CQ'},
#    'rating': 3.7,
#    'reference': 'ChIJsxDClU2dwpQRChZOS33Zup0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 85,
#    'vicinity': 'R. Cipriano Marquês de Souza, 44 - Centro, Castro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -24.794936, 'lng': -50.0087762},
#     'viewport': {'northeast': {'lat': -24.79359532010728,
#       'lng': -50.00738977010728},
#      'southwest': {'lat': -24.79629497989272, 'lng': -50.01008942989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '2d13d58795005115fbb24332fda1c334c3f2c7d8',
#    'name': 'OYO Grande Hotel',
#    'place_id': 'ChIJsQHdKFCdwpQRmAbF0SiD2o8',
#    'plus_code': {'compound_code': '6X4R+2F Centro, Castro - State of Paraná, Brazil',
#     'global_code': '587F6X4R+2F'},
#    'rating': 0,
#    'reference': 'ChIJsQHdKFCdwpQRmAbF0SiD2o8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'R. Cipriano Marquês de Souza, 442 - Centro, Castro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -24.7892901, 'lng': -50.0173322},
#     'viewport': {'northeast': {'lat': -24.78788907010727,
#       'lng': -50.01602517010728},
#      'southwest': {'lat': -24.79058872989272, 'lng': -50.01872482989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '55b89194389b8956b392df96b3a4a66e8dfecd8b',
#    'name': 'Pousada Bela Vista',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111413460502211540684">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAHB0cu_4uG9CFZCZphIdb1aRW3DCWoeXe2k6wX3a-tKmnpr5_bomlPfffvCdDjLSiBw6ze50OpwSpIeU5TvCUC-kuviAzuVrqI8KNN5h-Cxn6W5QximxgT2oRboVYpbvxEhBdbE2JchiCeOokrzjrR9mPGhQMw6iZqimhubrbdg8za8k9s8B32w',
#      'width': 720}],
#    'place_id': 'ChIJ5y5ayKqCwpQRzPbIsr3LFdw',
#    'plus_code': {'compound_code': '6X6M+73 Centro, Castro - State of Paraná, Brazil',
#     'global_code': '587F6X6M+73'},
#    'rating': 4.4,
#    'reference': 'ChIJ5y5ayKqCwpQRzPbIsr3LFdw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 49,
#    'vicinity': 'R. Maestro Benedito Pereira, 1217 - Centro, Castro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -24.7897222, 'lng': -50.0063889},
#     'viewport': {'northeast': {'lat': -24.78835717010728,
#       'lng': -50.00510757010728},
#      'southwest': {'lat': -24.79105682989272, 'lng': -50.00780722989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '476248ddce19e40a3a18cd9837b36cd85c311b59',
#    'name': 'Buganville Palace Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2592,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102296162961275136395">ken ito</a>'],
#      'photo_reference': 'CmRaAAAA3G1LEl35dJARKgoGLz7GIRLeoy9PuMGJiViFqe0nUAhdCkVglTsRRSIIaCn_jJlQmC72wKaiJQ-aTDf-Dxi-YgRLIl88DW91rR9d281gqaPlfyaJYYUgb83hAZR0s42TEhBTYJWu6xvQN3rMpzCJHNQMGhQMlAXGzorIbP-9DYT3WjAkDIV8fA',
#      'width': 4608}],
#    'place_id': 'ChIJ627zz1OdwpQRoewwaxB-L0w',
#    'plus_code': {'compound_code': '6X6V+4C Centro, Castro - State of Paraná, Brazil',
#     'global_code': '587F6X6V+4C'},
#    'rating': 4.4,
#    'reference': 'ChIJ627zz1OdwpQRoewwaxB-L0w',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 475,
#    'vicinity': 'Praça Manoel Ribas, 99 - Centro, Castro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -24.789677, 'lng': -50.0062751},
#     'viewport': {'northeast': {'lat': -24.78840072010728,
#       'lng': -50.00494652010727},
#      'southwest': {'lat': -24.79110037989272, 'lng': -50.00764617989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'e2cddbce880380f5a2d18d5d126efe2b038608ef',
#    'name': 'Hotel Buganville Express',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2848,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105486276964746813605">Hotel Buganville Express</a>'],
#      'photo_reference': 'CmRaAAAA1HhoSmTO_LIicCNmfOD0rduKOtV07GmEdF3JFEMJQ6ehHmxuSMY7A90M3OXbxbBjuLpHuMxB2o0Vb7BG5Vt8EK0go1YLimOUuvJJsk-nxtofvhKGc0eRyoDZk3fbwb9NEhAbOYb_4vG_CWkGy6xswayFGhTlCEGPOsGYInCPtd1BnMHcAFKZzQ',
#      'width': 4113}],
#    'place_id': 'ChIJUezZyk2dwpQR1ZjJnd7AD1c',
#    'plus_code': {'compound_code': '6X6V+4F Centro, Castro - State of Paraná, Brazil',
#     'global_code': '587F6X6V+4F'},
#    'rating': 4.2,
#    'reference': 'ChIJUezZyk2dwpQR1ZjJnd7AD1c',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 199,
#    'vicinity': 'R. Mariana Marquês, 66 - Centro, Castro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -24.8033628, 'lng': -50.01184989999999},
#     'viewport': {'northeast': {'lat': -24.80204212010728,
#       'lng': -50.01048692010728},
#      'southwest': {'lat': -24.80474177989272, 'lng': -50.01318657989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '0d39a8c7c8f984e827e597c8ea556b4ed40f98c8',
#    'name': 'Urano Business Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 846,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116696959554679120379">A Google User</a>'],
#      'photo_reference': 'CmRaAAAA56j_qp6pj-pqOOXSq9c5ROY3phYkis0WaUj14yGWG4BLacdSAfl9amcVhY_8Yas7L4S4gZGz4oKziyzBDpmP_47rI37bb5gps-Dy__SQxsXUrxMshsB7hRclJ0Efme2_EhA91F5yU8vRI_qnoEETDg8cGhS2zVVwCd8wl6lWTjcZTNvjgFgftw',
#      'width': 1270}],
#    'place_id': 'ChIJi9dEocKdwpQRUff0guVU4C0',
#    'plus_code': {'compound_code': '5XWQ+M7 Vila Frei Mathias, Castro - State of Paraná, Brazil',
#     'global_code': '587F5XWQ+M7'},
#    'rating': 4.5,
#    'reference': 'ChIJi9dEocKdwpQRUff0guVU4C0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 72,
#    'vicinity': 'R. José Marques, 26 - Vila Frei Mathias, Castro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -24.8068516, 'lng': -49.9909305},
#     'viewport': {'northeast': {'lat': -24.80555837010728,
#       'lng': -49.98960082010728},
#      'southwest': {'lat': -24.80825802989272, 'lng': -49.99230047989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'c7a34af03c40392d6bbee8e451df2a555aaad0dd',
#    'name': 'HOTEL ALVORADA',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 768,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102083442909899398506">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAxADlMBzJfRirlDRa1CJlAhmUcYAj33JP9Q0CUrvoUYGsDfvFjk-rUiBqYA4H8hcW3JXJdHkeR_4wAnHhIDofZK1cxCLrIthwm56RDQJ1r_6wXfneH8UrBY4FOj4FGlHUEhDnAGWxZr64RIjfwSduNa0wGhT9m-HyW62rzxu6O7M-VnAzmHKZ8g',
#      'width': 1024}],
#    'place_id': 'ChIJ627zz1OdwpQRHRNEtBsXYWY',
#    'plus_code': {'compound_code': '52V5+7J Jardim Social Arapongas, Castro - State of Paraná, Brazil',
#     'global_code': '587G52V5+7J'},
#    'rating': 3.8,
#    'reference': 'ChIJ627zz1OdwpQRHRNEtBsXYWY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 181,
#    'vicinity': 'R. Genésio Araújo Barbosa, 297 - Jardim Social Arapongas, Castro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -24.8050327, 'lng': -49.9962692},
#     'viewport': {'northeast': {'lat': -24.80368347010727,
#       'lng': -49.99498122010728},
#      'southwest': {'lat': -24.80638312989272, 'lng': -49.99768087989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '57d9ffb49c29f851f9e94e3c8b73f9b07d8c9a50',
#    'name': 'Hotel e Restaurante Contorno Sul',
#    'photos': [{'height': 3096,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117622716361318052501">Wellinton Maia Polopes</a>'],
#      'photo_reference': 'CmRaAAAAbVJ0ZgsHmh9WFHPGtj_ygClZy4Fm549GBPclWiS1gduo25kBBKgZyI6HbBIXbbRyoBjfdHC7VNlTll4PDPEIyU016VS99HexlxNQDRHAFcbm7P5BvzlNT5vhwbAGXv-dEhAM7KgUtGxNt5I2dUi5GOGhGhTFrkZHBYmbYT0Rzw-JBFIHWvvlzA',
#      'width': 4128}],
#    'place_id': 'ChIJBSdMAhWdwpQRHTRhVxVWmRU',
#    'plus_code': {'compound_code': '52V3+XF Jardim das Araucarias, Castro - State of Paraná, Brazil',
#     'global_code': '587G52V3+XF'},
#    'rating': 4,
#    'reference': 'ChIJBSdMAhWdwpQRHTRhVxVWmRU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 323,
#    'vicinity': 'R. Moacir Elías Fadel, 415 - Jardim das Araucarias, Castro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -24.7807113, 'lng': -49.98682830000001},
#     'viewport': {'northeast': {'lat': -24.77934727010728,
#       'lng': -49.98548122010728},
#      'southwest': {'lat': -24.78204692989272, 'lng': -49.98818087989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'ba8742d7e8067584ddcf34114fffbb8894b78d62',
#    'name': 'CHACARA BAILLY',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106281163871812624561">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAghb72_vMymuAmvHy6jFvFlBi7OWJ57_y5VUdRx5Xoy-AvQcUxLFxgSw5Dxdig-ThB4SnccG52SR_joW_J8dMvTReGxcJwWV_t1FB8GzqarI9QYUpPyjSOG5Lu9UvGvJ1EhCuXeZM3fC5lzhIYShUB2S9GhRXIoDKgeM7Tjn0cV1KUgrTCmWPoQ',
#      'width': 1280}],
#    'place_id': 'ChIJrWXORy2dwpQRhR-F4Q1MJdg',
#    'plus_code': {'compound_code': '6297+P7 Jardim das Nacoes, Castro - State of Paraná, Brazil',
#     'global_code': '587G6297+P7'},
#    'rating': 4.1,
#    'reference': 'ChIJrWXORy2dwpQRhR-F4Q1MJdg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 36,
#    'vicinity': 'R. Matilde Baer, 527 - Jardim das Nacoes, Castro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -24.8055456, 'lng': -50.002877},
#     'viewport': {'northeast': {'lat': -24.80431707010728,
#       'lng': -50.00154967010727},
#      'southwest': {'lat': -24.80701672989272, 'lng': -50.00424932989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '0958bcd3f1858b2f610c34d1a6a67c1c0afe0ce9',
#    'name': "Hotel D'Lucas",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2592,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115083540204274345045">Lucas Marcondes</a>'],
#      'photo_reference': 'CmRaAAAAUsaauRNJJC7ZqgXgk-WUCXN6lLMGP3jJMNfwjST1rP2FNrUBB6FDtk0klM8BtgnTX3yaMjKbhM8ddrVze9uC7VyPJZLVaaOUEOTe9yRP3QP1IrtypPVQqgl86GQWYTFUEhDYLPvjt3CgafZM3sWOYix7GhQHQDrNyCNgTSDZZBo18XOcu3urTg',
#      'width': 4608}],
#    'place_id': 'ChIJZdXVGmqdwpQR2GrpefKpPc0',
#    'plus_code': {'compound_code': '5XVW+QR Jardim Colonial, Castro - State of Paraná, Brazil',
#     'global_code': '587F5XVW+QR'},
#    'rating': 3.8,
#    'reference': 'ChIJZdXVGmqdwpQR2GrpefKpPc0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 40,
#    'vicinity': 'Av. Pref. Ronie Cardoso, 951 - Jardim Colonial, Castro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -24.8356867, 'lng': -50.024648},
#     'viewport': {'northeast': {'lat': -24.83433742010728,
#       'lng': -50.02329677010728},
#      'southwest': {'lat': -24.83703707989272, 'lng': -50.02599642989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '21fd252bb3902ccc8f5041c9e8d6fd61379a7d85',
#    'name': 'Motel Dallas',
#    'photos': [{'height': 4608,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102053314427147578797">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAVrj2KDbR-tZbHCruPC3vqRPLAh8bSzX1JqnMSIoqtG9qLVxJ67_b2SJzEXhv3lnYhkF7szX1mGc_lx6SPJvJnmRhdKKQ_w94SZS4V3SNo4QfLM4bAqAdzQo9fIV8zizFEhBoYyzh_qoZM4jdLEHhzI_OGhRffoCD1gY-NFvsSoPTp9DP5nXFAA',
#      'width': 3456}],
#    'place_id': 'ChIJfWXjbXsn6JQRNJY8hwIQ6-w',
#    'plus_code': {'compound_code': '5X7G+P4 Castro, State of Paraná, Brazil',
#     'global_code': '587F5X7G+P4'},
#    'rating': 3.5,
#    'reference': 'ChIJfWXjbXsn6JQRNJY8hwIQ6-w',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 42,
#    'vicinity': 'Castro'}],
#  'status': 'OK'}

# %%
#Trying to add to df but it just adds to the whole colun
testdata['results'][0]['name']
hotel_df.loc[hotel_df.index[0], 'Hotel Name'] = testdata['results'][0]['name']
hotel_df.head()
# Out:
# C:\Users\flier\.conda\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#    index          City    Lat    Long  Max Temp  Humidity  Cloudiness (%)  \
# 0      8        Castro -24.79  -50.01    293.58        59             100
# 1     13       Qaanaaq  77.48  -69.36    280.66        56               0
# 2     25  Punta Arenas -53.15  -70.92    274.15        59              74
# 3     31    Chokurdakh  70.63  147.92    295.81        44             100
# 4     32      Cherskiy  68.75  161.30    295.91        50               0
#
#    Wind Speed (m/s) Country        Date  Max Temp Fahrenheit  \
# 0              2.84      BR  1595705242                69.04
# 1              1.01      GL  1595705254                45.79
# 2              4.60      CL  1595705222                34.07
# 3              2.71      RU  1595705301                73.06
# 4              1.55      RU  1595705303                73.24
#
#                            Hotel Name
# 0  Central Palace Hotel - Castro (PR)
# 1  Central Palace Hotel - Castro (PR)
# 2  Central Palace Hotel - Castro (PR)
# 3  Central Palace Hotel - Castro (PR)
# 4  Central Palace Hotel - Castro (PR)

# %%
hotel_df.head()
# Out:
#    index          City    Lat    Long  Max Temp  Humidity  Cloudiness (%)  \
# 0      8        Castro -24.79  -50.01    293.58        59             100
# 1     13       Qaanaaq  77.48  -69.36    280.66        56               0
# 2     25  Punta Arenas -53.15  -70.92    274.15        59              74
# 3     31    Chokurdakh  70.63  147.92    295.81        44             100
# 4     32      Cherskiy  68.75  161.30    295.91        50               0
#
#    Wind Speed (m/s) Country        Date  Max Temp Fahrenheit Hotel Name
# 0              2.84      BR  1595705242                69.04
# 1              1.01      GL  1595705254                45.79
# 2              4.60      CL  1595705222                34.07
# 3              2.71      RU  1595705301                73.06
# 4              1.55      RU  1595705303                73.24

# %%
#Go thru ideal df list and store first hotel result in df 
for index, row in hotels_df.iterrows():

    # get city name from df
    city_name = row['City']

    # add keyword to params dict
    params['keyword'] = city_name

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {city_name}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    try:
        print(f"Nearest hotel to {city_name} is {results[0]['name']}.")
        
        hotel_df.loc[index, 'Hotel Name'] = results[0]['name']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display figure
