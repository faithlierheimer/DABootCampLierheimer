# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather = pd.read_csv('../weatherPy/weather_data.csv')
weather = weather.drop('Unnamed: 0', axis = 1)

# %%
weather.head()
# Out:
#         City    Lat    Long  Max Temp  Humidity  Cloudiness (%)  \
# 0    Rikitea -23.12 -134.97    293.95        80              12
# 1    Ushuaia -54.80  -68.30    272.15        92              40
# 2   Saldanha -33.01   17.94    288.15        77               0
# 3  Bariloche -41.15  -71.31    274.15       100              75
# 4       Hilo  19.73 -155.09    301.15        65              90
#
#    Wind Speed (m/s) Country        Date  Max Temp Fahrenheit
# 0              9.84      PF  1595705224                69.71
# 1              9.30      AR  1595705226                30.47
# 2              0.50      ZA  1595705229                59.27
# 3              4.60      AR  1595705231                34.07
# 4              3.10      US  1595705233                82.67

# %%
#Lat/long list
lat = weather['Lat'].tolist()
long = weather['Long'].tolist()
coordinates = list(zip(lat, long))
coordinates
# Out:
# [(-23.12, -134.97),
#  (-54.8, -68.3),
#  (-33.01, 17.94),
#  (-41.15, -71.31),
#  (19.73, -155.09),
#  (62.46, -114.35),
#  (62.27, 24.7),
#  (-13.88, 167.55),
#  (-24.79, -50.01),
#  (-0.48, 15.9),
#  (35.13, 140.3),
#  (-33.93, 18.42),
#  (14.4, 46.47),
#  (77.48, -69.36),
#  (-34.42, 19.23),
#  (-21.36, 55.77),
#  (-20.52, 57.52),
#  (22.08, -159.32),
#  (71.29, -156.79),
#  (59.7, 30.79),
#  (42.1, -79.24),
#  (-46.6, 168.33),
#  (32.69, 128.84),
#  (-46.28, 169.85),
#  (34.64, -120.46),
#  (-53.15, -70.92),
#  (-46.19, 168.86),
#  (31.61, 34.76),
#  (-21.2, -175.2),
#  (-0.13, -67.09),
#  (46.43, 26.4),
#  (70.63, 147.92),
#  (68.75, 161.3),
#  (43.52, -8.15),
#  (-3.14, -58.44),
#  (47.62, -57.62),
#  (-6.88, 112.21),
#  (-34.53, 20.04),
#  (57.05, -135.33),
#  (19.73, 96.22),
#  (78.22, 15.64),
#  (40.83, -6.0),
#  (-15.86, -38.88),
#  (68.05, 39.51),
#  (28.46, 119.91),
#  (43.88, -91.24),
#  (28.82, 115.43),
#  (-8.47, 140.33),
#  (-33.92, 25.57),
#  (71.92, 114.08),
#  (61.67, 96.37),
#  (12.52, -70.03),
#  (39.18, -84.53),
#  (-0.81, 12.73),
#  (42.6, -73.97),
#  (65.7, 82.47),
#  (52.37, 9.73),
#  (45.02, -93.22),
#  (4.14, 96.13),
#  (-3.8, 102.27),
#  (64.5, -165.41),
#  (26.12, 127.67),
#  (8.0, 124.29),
#  (69.45, -133.04),
#  (71.97, 102.5),
#  (-31.95, 141.43),
#  (4.41, 114.01),
#  (-20.73, 139.5),
#  (-20.74, 116.85),
#  (41.14, -73.36),
#  (-34.65, 148.03),
#  (-33.65, 115.33),
#  (-16.43, -51.82),
#  (41.65, 26.47),
#  (57.79, -152.41),
#  (42.25, -75.83),
#  (-0.74, -90.35),
#  (-38.0, -57.56),
#  (29.57, -104.42),
#  (60.14, -45.24),
#  (-28.78, 32.04),
#  (7.53, -12.51),
#  (64.38, -173.3),
#  (-32.72, 152.15),
#  (54.43, 31.9),
#  (43.8, 87.6),
#  (72.79, -56.15),
#  (69.38, 178.42),
#  (-10.62, 150.67),
#  (-21.21, -159.78),
#  (55.74, -97.86),
#  (58.45, 92.17),
#  (13.22, -59.52),
#  (45.52, -122.68),
#  (26.98, 83.11),
#  (47.67, -52.73),
#  (61.28, 108.01),
#  (69.41, 86.18),
#  (28.37, 129.48),
#  (66.42, 112.4),
#  (65.61, -37.64),
#  (-33.02, 27.91),
#  (66.04, -17.34),
#  (-19.84, 34.84),
#  (51.03, 90.23),
#  (22.29, 114.16),
#  (28.78, 105.09),
#  (-42.78, 147.06),
#  (64.25, -15.21),
#  (64.84, -147.72),
#  (50.15, 48.57),
#  (-42.88, 147.33),
#  (18.69, 12.92),
#  (-22.96, 14.51),
#  (-16.92, 35.26),
#  (19.22, -104.7),
#  (-23.44, -51.87),
#  (-5.2, -35.46),
#  (58.16, 28.19),
#  (-9.6, -35.96),
#  (51.2, 136.67),
#  (11.75, 11.96),
#  (44.85, 34.97),
#  (24.69, 46.72),
#  (-19.55, 169.27),
#  (-45.87, 170.5),
#  (43.75, -81.72),
#  (19.28, -81.25),
#  (60.1, 19.93),
#  (-8.14, 159.59),
#  (-2.06, 29.35),
#  (33.19, -82.53),
#  (-33.59, 26.89),
#  (56.78, 46.87),
#  (71.04, 27.85),
#  (32.67, -17.1),
#  (-46.13, 167.68),
#  (-10.45, 161.92),
#  (-2.92, -39.92),
#  (73.51, 80.55),
#  (-33.7, -53.46),
#  (-20.23, 164.02),
#  (68.22, -135.01),
#  (-21.21, -50.43),
#  (43.32, 145.57),
#  (69.7, 170.31),
#  (48.38, -4.62),
#  (-3.67, 152.43),
#  (38.89, -76.51),
#  (41.37, -73.41),
#  (-9.8, -139.03),
#  (8.13, 77.3),
#  (65.85, 44.24),
#  (63.05, 179.32),
#  (48.68, 71.64),
#  (38.5, 102.17),
#  (-25.24, 130.99),
#  (-2.57, 150.8),
#  (-3.98, -38.73),
#  (41.12, 80.26),
#  (22.24, 68.97),
#  (68.53, 146.42),
#  (-16.62, -72.71),
#  (51.5, -107.05),
#  (7.04, 134.26),
#  (-19.06, -169.92),
#  (64.9, 45.76),
#  (-0.6, 73.08),
#  (66.77, 123.37),
#  (20.13, 85.1),
#  (21.48, 109.1),
#  (5.35, 48.53),
#  (18.02, 121.18),
#  (-10.41, -36.43),
#  (55.94, 110.1),
#  (-23.13, 150.73),
#  (-21.05, 31.67),
#  (38.52, -28.7),
#  (-15.68, -38.95),
#  (-10.34, -67.19),
#  (-23.7, 133.88),
#  (48.01, 91.64),
#  (5.03, 21.21),
#  (12.18, 125.51),
#  (31.77, 104.72),
#  (-8.77, 160.7),
#  (-20.34, 57.76),
#  (9.49, 76.33),
#  (54.77, -101.86),
#  (-26.18, -58.18),
#  (-24.87, 113.63),
#  (5.56, 95.32),
#  (7.77, -72.22),
#  (-17.93, 19.77),
#  (32.35, -90.88),
#  (11.67, 92.75),
#  (12.48, -16.55),
#  (61.58, -149.44),
#  (30.65, -91.16),
#  (-9.29, -76.01),
#  (66.08, 76.63),
#  (-38.65, 178.0),
#  (16.98, 73.3),
#  (69.3, 139.9),
#  (11.0, 122.67),
#  (-20.57, 164.28),
#  (6.5, 2.6),
#  (-6.34, 106.1),
#  (66.56, 67.8),
#  (-14.66, 17.69),
#  (19.87, 72.7),
#  (39.89, 4.27),
#  (44.26, 38.86),
#  (51.38, 1.39),
#  (-25.3, 152.85),
#  (-10.75, -77.77),
#  (37.08, 57.51),
#  (47.45, -79.64),
#  (50.7, -127.42),
#  (68.71, -52.87),
#  (10.92, -7.0),
#  (34.98, 139.87),
#  (-20.32, 118.57),
#  (47.8, 67.71),
#  (-13.7, -76.22),
#  (59.64, 17.08),
#  (10.93, 108.1),
#  (-10.88, 26.6),
#  (41.82, 140.65)]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#Configure gmaps
gmaps.configure(api_key=g_key)

# %%
#Configure the map layout
figure_layout = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %%
#Add markers corresponding to coordinates of each city
markers = gmaps.marker_layer(coordinates)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %%
weather.head()
humidity = weather.Humidity
type(humidity)
# Out:
# pandas.core.series.Series

# %%
#Add heatmap layer
heat_layer = gmaps.heatmap_layer(coordinates, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#Ideal weather conditions for me: max temp 77 deg fahrenheit or below, windspeed below 5 m/s, humidity 60% or below
weather_ideal = weather[weather['Wind Speed (m/s)']<5]
weather_ideal = weather_ideal[weather_ideal['Max Temp Fahrenheit']<77]
weather_ideal = weather_ideal[weather_ideal['Humidity']<60]
weather_ideal = weather_ideal.reset_index()
weather_ideal.head()
# Out:
#    index          City    Lat    Long  Max Temp  Humidity  Cloudiness (%)  \
# 0      8        Castro -24.79  -50.01    293.58        59             100
# 1     13       Qaanaaq  77.48  -69.36    280.66        56               0
# 2     25  Punta Arenas -53.15  -70.92    274.15        59              74
# 3     31    Chokurdakh  70.63  147.92    295.81        44             100
# 4     32      Cherskiy  68.75  161.30    295.91        50               0
#
#    Wind Speed (m/s) Country        Date  Max Temp Fahrenheit
# 0              2.84      BR  1595705242                69.04
# 1              1.01      GL  1595705254                45.79
# 2              4.60      CL  1595705222                34.07
# 3              2.71      RU  1595705301                73.06
# 4              1.55      RU  1595705303                73.24

# %%
#Drop nulls
weather_ideal_no_null = weather_ideal.dropna()
weather_ideal_no_null.head()
# Out:
#    index          City    Lat    Long  Max Temp  Humidity  Cloudiness (%)  \
# 0      8        Castro -24.79  -50.01    293.58        59             100
# 1     13       Qaanaaq  77.48  -69.36    280.66        56               0
# 2     25  Punta Arenas -53.15  -70.92    274.15        59              74
# 3     31    Chokurdakh  70.63  147.92    295.81        44             100
# 4     32      Cherskiy  68.75  161.30    295.91        50               0
#
#    Wind Speed (m/s) Country        Date  Max Temp Fahrenheit
# 0              2.84      BR  1595705242                69.04
# 1              1.01      GL  1595705254                45.79
# 2              4.60      CL  1595705222                34.07
# 3              2.71      RU  1595705301                73.06
# 4              1.55      RU  1595705303                73.24

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#Store ideal cities/weather into a variable called hotel_df
hotel_df = weather_ideal_no_null
hotel_df.head()
# Out:
#    index          City    Lat    Long  Max Temp  Humidity  Cloudiness (%)  \
# 0      8        Castro -24.79  -50.01    293.58        59             100
# 1     13       Qaanaaq  77.48  -69.36    280.66        56               0
# 2     25  Punta Arenas -53.15  -70.92    274.15        59              74
# 3     31    Chokurdakh  70.63  147.92    295.81        44             100
# 4     32      Cherskiy  68.75  161.30    295.91        50               0
#
#    Wind Speed (m/s) Country        Date  Max Temp Fahrenheit
# 0              2.84      BR  1595705242                69.04
# 1              1.01      GL  1595705254                45.79
# 2              4.60      CL  1595705222                34.07
# 3              2.71      RU  1595705301                73.06
# 4              1.55      RU  1595705303                73.24

# %%
#Ideal locations coordinates
ideal_lat = hotel_df['Lat'].tolist()
ideal_long = hotel_df['Long'].tolist()
ideal_coord = list(zip(ideal_lat, ideal_long))
#ideal_coord

# %%
#Add 'hotel name' column to the df
hotel_df['Hotel Name'] = ''
#hotel_df.count()
# Out:
# C:\Users\flier\.conda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
count1 = 0
count2 = 1

# %%
#Length of ideal coordinates is an even number, maybe turn it into a list and then just call every 2 indices??? 
ideal_coords_list = [item for t in ideal_coord for item in t]
#Ideal coords list is 100, so we should call every 2 items in it....

# %%
#Params for google API search for hotels within 5000 m
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": "",  #testing out ideal coordinate list,
    "radius": 5000,
    "types": "lodging",
    "key": g_key
}

# %%
#Test response to make sure everything is working right
testdata = testresponse.json()
testdata['results'][0]['name']
#Test data is showing me that my method of referring to the coordinates using string notation works when I just do one, so why isn't the loop working??
# Out:
# 'CHACARA BAILLY'

# %%
#Practice API call for first place on list
testresponse = requests.get(base_url, params=params)

# %%
#Adding test data result to frame--IT WORKED THIS TIME ?! NELSON HELP 
#testdata['results'][0]['name']
# hotel_df.loc[hotel_df.index[0], 'Hotel Name'] = testdata['results'][0]['name']
# #hotel_df.loc[hotel_df.index[0], 'Hotel Name' ] = 'foo'
# hotel_df.head()

# %%
str(ideal_coords_list[count1]) + "," + str(ideal_coords_list[count2])
# Out:
# '-24.79,-50.01'

# %%
#Testing to make sure parameters list updates correctly 
# count1 = 0
# count2 = 1
# for index, row in hotel_df.iterrows(): 
#     params['location'] = str(ideal_coords_list[count1]) + "," + str(ideal_coords_list[count2])
#     count1+=2
#     count2+=2
#     print(params)
# Out:
# 0

# %%
#Go thru ideal df list and store first hotel result in df 
count1 = 0
count2 = 1
for index, row in hotel_df.iterrows():

    # get city name from df
    city_name = row['City']  

    # add keyword to params dict
     #Works
    params['location'] = str(ideal_coords_list[count1]) + "," + str(ideal_coords_list[count2]) #DOES NOT WORK
    count1+=2
    count2+=2

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {city_name}.")
    response = requests.get(base_url, params=params).json()
    
    
    
    
    try:
        print(f"Nearest hotel to {city_name} is {response['results'][0]['name']}.")
        
        hotel_df.loc[index, 'Hotel Name'] = response['results'][0]['name']

    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Retrieving Results for Index 0: Castro.
# Nearest hotel to Castro is CHACARA BAILLY.
# ------------
# Retrieving Results for Index 1: Qaanaaq.
# C:\Users\flier\.conda\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Nearest hotel to Qaanaaq is Qaanaaq Hotel.
# ------------
# Retrieving Results for Index 2: Punta Arenas.
# Nearest hotel to Punta Arenas is Hotel Dreams Del Estrecho.
# ------------
# Retrieving Results for Index 3: Chokurdakh.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 4: Cherskiy.
# Nearest hotel to Cherskiy is Gostinitsa.
# ------------
# Retrieving Results for Index 5: Port Elizabeth.
# Nearest hotel to Port Elizabeth is 39 On Nile Guest House.
# ------------
# Retrieving Results for Index 6: Portland.
# Nearest hotel to Portland is Portland Marriott City Center.
# ------------
# Retrieving Results for Index 7: East London.
# Nearest hotel to East London is Tu Casa.
# ------------
# Retrieving Results for Index 8: Aleksandrov Gay.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 9: Dunedin.
# Nearest hotel to Dunedin is Scenic Hotel Southern Cross.
# ------------
# Retrieving Results for Index 10: Jinchang.
# Nearest hotel to Jinchang is Mingshihui Jinchang International Hotel.
# ------------
# Retrieving Results for Index 11: Outlook.
# Nearest hotel to Outlook is Red Wheel Motel.
# ------------
# Retrieving Results for Index 12: Khovd.
# Nearest hotel to Khovd is Hotel Khovd.
# ------------
# Retrieving Results for Index 13: Formosa.
# Nearest hotel to Formosa is Asterión Hotel.
# ------------
# Retrieving Results for Index 15: Ust-Nera.
# Nearest hotel to Ust-Nera is Hotel Ust-Nera.
# ------------
# Retrieving Results for Index 16: San Jerónimo.
# Nearest hotel to San Jerónimo is Tuki Llajta Pueblo Bonito Eco Lodge.
# ------------
# Retrieving Results for Index 17: Bani Walid.
# Nearest hotel to Bani Walid is منزل الصابر أبوفانة.
# ------------
# Retrieving Results for Index 18: Norman Wells.
# Nearest hotel to Norman Wells is Heritage Hotel.
# ------------
# Retrieving Results for Index 19: Lucapa.
# Nearest hotel to Lucapa is Residência Ulisses Dos Santos.
# ------------
# Retrieving Results for Index 20: Arrondissement de Limoges.
# Nearest hotel to Arrondissement de Limoges is Hôtel Le Saint Eloi Logis & SPA - Restaurant C. Pasquier.
# ------------
# Retrieving Results for Index 21: Takāb.
# Nearest hotel to Takāb is مهمانپذیر تخت سلیمان.
# ------------
# Retrieving Results for Index 22: Nyamuswa.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 23: Ambilobe.
# Nearest hotel to Ambilobe is Hôtel & Restaurant DIANA Ambilobe.
# ------------
# Retrieving Results for Index 24: Veranópolis.
# Nearest hotel to Veranópolis is Verona Parque Hotel.
# ------------
# Retrieving Results for Index 25: Viedma.
# Nearest hotel to Viedma is Hotel Cristal.
# ------------
# Retrieving Results for Index 26: Kurchum.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 27: Coquimbo.
# Nearest hotel to Coquimbo is Hotel San Juan.
# ------------
# Retrieving Results for Index 28: Kruisfontein.
# Nearest hotel to Kruisfontein is Oyster Bay House Rental.
# ------------
# Retrieving Results for Index 29: Shubarshi.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 30: Fort Nelson.
# Nearest hotel to Fort Nelson is The Fort Nelson Hotel.
# ------------
# Retrieving Results for Index 31: Kalispell.
# Nearest hotel to Kalispell is Red Lion Hotel Kalispell.
# ------------
# Retrieving Results for Index 32: Mwanza.
# Nearest hotel to Mwanza is Gold Crest Hotel.
# ------------
# Retrieving Results for Index 33: Khandyga.
# Nearest hotel to Khandyga is Apel'sin.
# ------------
# Retrieving Results for Index 34: Şırnak.
# Nearest hotel to Şırnak is Şehr-i Nuh Otel.
# ------------
# Retrieving Results for Index 35: Tres Arroyos.
# Nearest hotel to Tres Arroyos is Habitacion Triple con baño y entrada privada.
# ------------
# Retrieving Results for Index 36: Cap Malheureux.
# Nearest hotel to Cap Malheureux is Pereybere Hotel & Spa.
# ------------
# Retrieving Results for Index 38: Kaoma.
# Nearest hotel to Kaoma is KAOMA AIRPORT.
# ------------
# Retrieving Results for Index 40: Leh.
# Nearest hotel to Leh is Hotel Ladakh Greens.
# ------------
# Retrieving Results for Index 41: Odesa.
# Nearest hotel to Odesa is Londonskaya Hotel.
# ------------
# Retrieving Results for Index 43: Grand Gaube.
# Nearest hotel to Grand Gaube is Veranda Paul et Virginie Hotel & Spa.
# ------------
# Retrieving Results for Index 44: Mikhaylovka.
# Nearest hotel to Mikhaylovka is 5 Komnat.
# ------------
# Retrieving Results for Index 45: Athabasca.
# Nearest hotel to Athabasca is Athabasca Lodge Motel.
# ------------
# Retrieving Results for Index 46: Seymchan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 47: Malanje.
# Nearest hotel to Malanje is Malanje Hotel.
# ------------
# Retrieving Results for Index 48: Pergamino.
# Nearest hotel to Pergamino is Hotel Fachinat.
# ------------
# Retrieving Results for Index 49: Deputatsky.
# Nearest hotel to Deputatsky is Baza Otdykha.
# ------------
# Retrieving Results for Index 50: Menongue.
# Nearest hotel to Menongue is Ritz Lauca.
# ------------
# Retrieving Results for Index 51: Zhezkazgan.
# Nearest hotel to Zhezkazgan is Kvartiry Posutochno..
# ------------
# Retrieving Results for Index 52: Enköping.
# Nearest hotel to Enköping is Best Western Hotel Park Astoria.
# ------------
# Retrieving Results for Index 53: Kambove.
# Nearest hotel to Kambove is Couvant des soeurs catholiques.
# ------------

# %%
#Print out hotels df for ideal cities and make sure it's populating the hotel name field 
hotel_df
# Out:
#     index                       City    Lat    Long  Max Temp  Humidity  \
# 0       8                     Castro -24.79  -50.01    293.58        59
# 1      13                    Qaanaaq  77.48  -69.36    280.66        56
# 2      25               Punta Arenas -53.15  -70.92    274.15        59
# 3      31                 Chokurdakh  70.63  147.92    295.81        44
# 4      32                   Cherskiy  68.75  161.30    295.91        50
# 5      48             Port Elizabeth -33.92   25.57    290.15        39
# 6      93                   Portland  45.52 -122.68    294.82        59
# 7     101                East London -33.02   27.91    294.98        27
# 8     110            Aleksandrov Gay  50.15   48.57    294.11        43
# 9     125                    Dunedin -45.87  170.50    282.59        56
# 10    155                   Jinchang  38.50  102.17    295.32        26
# 11    163                    Outlook  51.50 -107.05    292.04        51
# 12    181                      Khovd  48.01   91.64    291.30        47
# 13    189                    Formosa -26.18  -58.18    288.15        51
# 15    202                   Ust-Nera  64.57  143.20    296.16        44
# 16    206               San Jerónimo -11.95  -75.28    288.72        36
# 17    236                 Bani Walid  31.76   13.99    297.54        46
# 18    249               Norman Wells  65.28 -126.83    295.15        43
# 19    269                     Lucapa  -8.42   20.74    293.67        25
# 20    283  Arrondissement de Limoges  45.75    1.33    295.15        56
# 21    295                      Takāb  36.40   47.11    294.68        33
# 22    299                   Nyamuswa  -1.90   34.02    297.15        57
# 23    314                   Ambilobe -13.20   49.05    296.09        52
# 24    322                Veranópolis -28.94  -51.55    288.15        53
# 25    341                     Viedma -40.81  -63.00    284.26        52
# 26    345                    Kurchum  48.57   83.65    294.33        51
# 27    377                   Coquimbo -29.95  -71.34    292.15        34
# 28    383               Kruisfontein -34.00   24.73    289.35        45
# 29    396                  Shubarshi  48.59   57.19    295.63        42
# 30    399                Fort Nelson  58.81 -122.70    293.15        45
# 31    431                  Kalispell  48.20 -114.31    297.59        33
# 32    433                     Mwanza  -2.52   32.90    295.15        46
# 33    442                   Khandyga  62.67  135.60    291.34        54
# 34    451                     Şırnak  37.52   42.46    293.74        24
# 35    458               Tres Arroyos -38.37  -60.28    283.58        59
# 36    460             Cap Malheureux -19.98   57.61    293.71        58
# 38    474                      Kaoma -14.78   24.80    286.42        53
# 40    483                        Leh  34.17   77.58    290.71        39
# 41    484                      Odesa  46.48   30.73    295.15        43
# 43    503                Grand Gaube -20.01   57.66    293.71        58
# 44    509                Mikhaylovka  50.06   43.24    290.93        49
# 45    514                  Athabasca  54.72 -113.29    292.93        56
# 46    532                   Seymchan  62.88  152.43    294.11        46
# 47    533                    Malanje  -9.54   16.34    291.20        27
# 48    536                  Pergamino -33.89  -60.57    288.15        34
# 49    551                 Deputatsky  69.30  139.90    294.29        43
# 50    557                   Menongue -14.66   17.69    285.55        41
# 51    571                 Zhezkazgan  47.80   67.71    294.61        53
# 52    573                   Enköping  59.64   17.08    291.15        48
# 53    575                    Kambove -10.88   26.60    285.67        56
#
#     Cloudiness (%)  Wind Speed (m/s) Country        Date  Max Temp Fahrenheit  \
# 0              100              2.84      BR  1595705242                69.04
# 1                0              1.01      GL  1595705254                45.79
# 2               74              4.60      CL  1595705222                34.07
# 3              100              2.71      RU  1595705301                73.06
# 4                0              1.55      RU  1595705303                73.24
# 5                0              2.60      ZA  1595705342                62.87
# 6               20              2.60      US  1595705259                71.28
# 7                0              4.72      ZA  1595705488                71.56
# 8              100              3.92      RU  1595705510                70.00
# 9               49              0.89      NZ  1595705552                49.26
# 10               0              4.17      CN  1595705624                72.18
# 11              80              3.13      CA  1595705643                66.27
# 12               3              2.34      MN  1595705633                64.94
# 13               0              3.60      AR  1595705713                59.27
# 15             100              1.97      RU  1595705576                73.69
# 16              89              1.11      PE  1595705757                60.30
# 17               0              3.76      LY  1595705836                76.17
# 18              75              1.00      CA  1595705498                71.87
# 19               0              1.67      AO  1595705918                69.21
# 20              97              2.60      FR  1595705952                71.87
# 21              52              1.58      IR  1595705982                71.02
# 22               5              2.60      TZ  1595705992                75.47
# 23             100              2.75      MG  1595706027                73.56
# 24             100              0.45      BR  1595706046                59.27
# 25             100              4.92      AR  1595705528                52.27
# 26               7              4.17      KZ  1595706104                70.39
# 27              88              3.10      CL  1595705973                66.47
# 28               0              4.57      ZA  1595706201                61.43
# 29               0              4.29      KZ  1595706234                72.73
# 30              75              4.60      CA  1595706241                68.27
# 31               1              1.43      US  1595706319                76.26
# 32               4              2.60      TZ  1595706324                71.87
# 33              37              2.96      RU  1595706345                65.01
# 34               0              1.46      TR  1595706371                69.33
# 35              27              4.86      AR  1595706389                51.04
# 36              46              4.02      MU  1595706394                69.28
# 38               0              3.25      ZM  1595706429                56.16
# 40               9              0.76      IN  1595706451                63.88
# 41              64              1.00      UA  1595706454                71.87
# 43              59              4.02      MU  1595706497                69.28
# 44               0              0.89      RU  1595706512                64.27
# 45               6              4.61      CA  1595706523                67.87
# 46              19              3.89      RU  1595706569                70.00
# 47               0              1.48      AO  1595706572                64.76
# 48              53              0.45      AR  1595706584                59.27
# 49              17              2.07      RU  1595706619                70.32
# 50              39              2.02      AO  1595706634                54.59
# 51               0              2.82      KZ  1595706669                70.90
# 52              29              2.10      SE  1595706674                64.67
# 53               2              1.85      CD  1595706681                54.81
#
#                                            Hotel Name
# 0                                      CHACARA BAILLY
# 1                                       Qaanaaq Hotel
# 2                           Hotel Dreams Del Estrecho
# 3
# 4                                          Gostinitsa
# 5                              39 On Nile Guest House
# 6                       Portland Marriott City Center
# 7                                             Tu Casa
# 8
# 9                         Scenic Hotel Southern Cross
# 10            Mingshihui Jinchang International Hotel
# 11                                    Red Wheel Motel
# 12                                        Hotel Khovd
# 13                                     Asterión Hotel
# 15                                     Hotel Ust-Nera
# 16                Tuki Llajta Pueblo Bonito Eco Lodge
# 17                                منزل الصابر أبوفانة
# 18                                     Heritage Hotel
# 19                      Residência Ulisses Dos Santos
# 20  Hôtel Le Saint Eloi Logis & SPA - Restaurant C...
# 21                               مهمانپذیر تخت سلیمان
# 22
# 23                  Hôtel & Restaurant DIANA Ambilobe
# 24                                Verona Parque Hotel
# 25                                      Hotel Cristal
# 26
# 27                                     Hotel San Juan
# 28                            Oyster Bay House Rental
# 29
# 30                              The Fort Nelson Hotel
# 31                           Red Lion Hotel Kalispell
# 32                                   Gold Crest Hotel
# 33                                           Apel'sin
# 34                                    Şehr-i Nuh Otel
# 35       Habitacion Triple con baño y entrada privada
# 36                              Pereybere Hotel & Spa
# 38                                      KAOMA AIRPORT
# 40                                Hotel Ladakh Greens
# 41                                  Londonskaya Hotel
# 43               Veranda Paul et Virginie Hotel & Spa
# 44                                           5 Komnat
# 45                              Athabasca Lodge Motel
# 46
# 47                                      Malanje Hotel
# 48                                     Hotel Fachinat
# 49                                       Baza Otdykha
# 50                                         Ritz Lauca
# 51                               Kvartiry Posutochno.
# 52                    Best Western Hotel Park Astoria
# 53                     Couvant des soeurs catholiques

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Long"]]

# %%
# Add marker layer ontop of heat map
figure_layout2 = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig2 = gmaps.figure(layout=figure_layout2)
fig2
markers2 = gmaps.marker_layer(ideal_coord)
fig2.add_layer(markers2)
fig2
#Add heatmap layer
heat_layer2 = gmaps.heatmap_layer(ideal_coord, weights=temp, 
                                 dissipating=False, max_intensity=76.26,
                                 point_radius = 1)

fig2.add_layer(heat_layer2)
fig2
# Display figure
#Each figure will have a similar looking temperature heatmap because I wanted them all to have a max temperature under 77 deg F
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %%
temp = hotel_df['Max Temp Fahrenheit']

# %%
hotel_df.max()
# Out:
# index                                   575
# City                                 Şırnak
# Lat                                   77.48
# Long                                  170.5
# Max Temp                             297.59
# Humidity                                 59
# Cloudiness (%)                          100
# Wind Speed (m/s)                       4.92
# Country                                  ZM
# Date                             1595706681
# Max Temp Fahrenheit                   76.26
# Hotel Name             مهمانپذیر تخت سلیمان
# dtype: object
